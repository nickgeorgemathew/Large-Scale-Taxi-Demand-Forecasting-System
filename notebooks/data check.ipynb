# %%
import pandas as pd

# %%
a=pd.read_parquet("C:/Users/nikhi/Downloads/yellow_tripdata_2022-03.parquet")
a=a.copy()

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3627882 entries, 0 to 3627881
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# ...

# %%
a.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-03-01 00:13:08   2022-03-01 00:24:35              1.0
# 1         1  2022-03-01 00:47:52   2022-03-01 01:00:08              1.0
# 2         2  2022-03-01 00:02:46   2022-03-01 00:46:43              1.0
# 3         2  2022-03-01 00:52:43   2022-03-01 01:03:40              2.0
# 4         2  2022-03-01 00:15:35   2022-03-01 00:34:13              1.0
# 5         1  2022-03-01 00:11:57   2022-03-01 00:53:05              2.0
# 6         2  2022-03-01 00:05:11   2022-03-01 00:08:22              1.0
# 7         2  2022-03-01 00:30:56   2022-03-01 00:46:21              1.0
# 8         2  2022-03-01 00:30:28   2022-03-01 00:30:36              1.0
# 9         2  2022-03-01 00:30:28   2022-03-01 00:30:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.40         1.0                  N            90           209
# ...

# %%
a["passenger_count"].value_counts()
# Out:
# passenger_count
# 1.0    2626588
# 2.0     509493
# 3.0     130829
# 0.0      74319
# 5.0      69333
# 4.0      53109
# 6.0      46365
# 7.0         22
# 8.0          9
# 9.0          1
# Name: count, dtype: int64

# %%
a["PULocationID"].value_counts()
# Out:
# PULocationID
# 237    168294
# 132    152733
# 161    152354
# 236    152289
# 162    122274
#         ...
# 184         1
# 2           1
# 251         1
# 214         1
# 245         1
# Name: count, Length: 257, dtype: int64

# %%
a["PULocationID"].sort_values(ascending=True)
# Out:
# 2306985      1
# 1059114      1
# 1518864      1
# 1275650      1
# 2825373      1
#           ...
# 3536577    265
# 3536579    265
# 2156211    265
# 3536582    265
# 2156027    265
# Name: PULocationID, Length: 3627882, dtype: int64

# %%
s=a[a["fare_amount"]>0]
c=s["fare_amount"].max()

c
# Out:
# np.float64(1777.0)

# %%
c=a[a["trip_distance"]>2000]
c["trip_distance"].value_counts(ascending=True)
# Out:
# trip_distance
# 53440.55     1
# 7170.55      1
# 59918.99     1
# 33249.83     1
# 85671.20     1
#             ..
# 54041.77     1
# 125804.71    1
# 181534.72    1
# 81060.74     1
# 78809.21     1
# Name: count, Length: 91, dtype: int64

# %%
a["passenger_count"].value_counts()
# Out:
# passenger_count
# 1.0    2626588
# 2.0     509493
# 3.0     130829
# 0.0      74319
# 5.0      69333
# 4.0      53109
# 6.0      46365
# 7.0         22
# 8.0          9
# 9.0          1
# Name: count, dtype: int64

# %%
a.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
d=pd.read_parquet("C:/Users/nikhi/Downloads/Large-Scale-Taxi-Demand-Forecasting-System/features_store/selected_features.parquet")

# %%
d.head(5)
# Out:
#        hour_timestamp  demand   avg_fare  avg_distance  zone_id  hour_of_day  \
# 0 2022-03-09 17:30:00     1.0   8.000000          1.87        4           17
# 1 2022-03-09 18:30:00     1.0  13.500000          3.47        4           18
# 2 2022-03-09 20:30:00     1.0  21.500000          6.76        4           20
# 3 2022-03-10 01:30:00     1.0  11.000000          3.03        4            1
# 4 2022-03-10 02:30:00     3.0  10.166667          1.92        4            2
#
#    day_of_week  month  is_weekend  is_rush_am  ...  roll_mean_24h  \
# 0            2      3           0           0  ...       3.083333
# 1            2      3           0           0  ...       3.000000
# 2            2      3           0           0  ...       3.000000
# 3            3      3           0           0  ...       3.000000
# 4            3      3           0           0  ...       2.875000
#
#    roll_mean_48h  roll_mean_168h  roll_std_6h  roll_std_24h  zone_mean_demand  \
# ...

# %%
dict1={"a":3,"b":2,"c":30}
dict2={"a":3,"b":2,"c":70}
b=max(dict1.items(),key=lambda x:x[1])
b=b[0]
b2=max(dict2.items(),key=lambda x:x[1])
b2=b2[0]
from collections import Counter
c=Counter(b)
c=c.most_common(n=1)
c[0][0]
# Out:
# 'c'

# %%
dict1["a"]
# Out:
# 3
